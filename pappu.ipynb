# %%
# !pip install inspect-it
import inspect
inspect.getfullargspec(dbutils.secrets.get)
# PRIVACY IN PYTHON-> MYTH!

# %%
dbutils.fs.mount(
    source = "wasbs://secret@pikapikatomato.blob.core.windows.net",
    mount_point = "/mnt/panda",
    extra_configs = {
        'fs.azure.account.key.pikapikatomato.blob.core.windows.net' : dbutils.secrets.get(key="accesskey", scope="databrickssecret")
    }
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: True</div>

# %%
data = spark.read.csv('/mnt/panda/data.csv', header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data.take(4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...
